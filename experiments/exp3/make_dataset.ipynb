# %% [markdown]
# # Make Dataset
# 7th August 2023
#
# Make dataset from csv run ouputs.
#
# The dataset already includes:
# * time
# * latitude
# * longitude
# * elevation
#
# Outputs need to be transformed using Box-Cox lambdas to include:
# * Transformed mean posterior predictions for the high fidelity level
# * Upper bound of the transformed posterior distribution for the high fidelity level
# * Lower bound of the transformed posterior distribution for the high fidelity level
#
# The data also needs to be converted to a netcdf file and include the appropriate metadata.

# %%
import pandas as pd
import scipy as sp
import numpy as np
import glob
import xarray as xr

# %% [markdown]
# ## For 1 year

# %%
df = pd.read_csv('outputs/priors_lat_lon_mat52/preds_1980_1981.csv', index_col=0)

# %%
df.head()
# Out:
#           time       lon       lat  elevation     pred0  pred_low0    y_var0  \
# 0  1980.041667  81.90625  30.28125     5383.0  0.314634   0.289611  2.243733
# 1  1980.041667  81.96875  30.28125     5071.0  0.254223   0.234005  2.151837
# 2  1980.041667  81.46875  30.34375     5446.0  0.133395   0.122786  2.498563
# 3  1980.041667  81.53125  30.34375     5237.0  0.019359   0.017819  2.273537
# 4  1980.041667  81.71875  30.34375     4978.0 -0.064907  -0.059745  2.139734
#
#    y_var_low0
# 0    0.606565
# 1    0.528705
# 2    0.822474
# 3    0.631817
# 4    0.518450

# %%
scaling_df = pd.read_csv('dataset_w_metadata/lambdas_1980_2010.csv', index_col=0)

# %%
scaling_df.head()
# Out:
#    year   lambdas
# 0  1980  0.058104
# 1  1981  0.120056
# 2  1982  0.129860
# 3  1983  0.135035
# 4  1984  0.111865

# %%
lambdas = scaling_df[['lambdas']]

# %%
lambdas
# Out:
#      lambdas
# 0   0.058104
# 1   0.120056
# 2   0.129860
# 3   0.135035
# 4   0.111865
# 5   0.086285
# 6   0.113906
# 7   0.182353
# 8   0.095554
# 9   0.059386
# 10  0.077071
# 11  0.126068
# 12  0.120604
# 13  0.108630
# 14  0.099836
# 15  0.032108
# 16  0.135304
# 17  0.068902
# 18  0.142976
# 19  0.122277
# 20  0.136641
# 21  0.098881
# 22  0.052161
# 23  0.133962
# 24  0.125177
# 25  0.123058
# 26  0.071828
# 27  0.106785
# 28  0.137860
# 29  0.094458

# %%
df['pred_tr'] = sp.special.inv_boxcox(df['pred0'], lambdas.iloc[0].values)

# %%
lambdas.iloc[0].values
# Out:
# array([0.05810437])

# %%
df.head()
# Out:
#           time       lon       lat  elevation     pred0  pred_low0    y_var0  \
# 0  2009.041667  81.90625  30.28125     5383.0 -0.409132  -0.396830  2.024798
# 1  2009.041667  81.96875  30.28125     5071.0 -0.518415  -0.502826  1.959358
# 2  2009.041667  81.46875  30.34375     5446.0 -0.419634  -0.407015  2.217617
# 3  2009.041667  81.53125  30.34375     5237.0 -0.564382  -0.547411  2.052127
# 4  2009.041667  81.71875  30.34375     4978.0 -0.634633  -0.615549  1.953001
#
#    y_var_low0   pred_tr  pred_tr_CI_upper  pred_tr_CI_lower
# 0    0.615223  0.660952          9.291180          0.029068
# 1    0.553659  0.590737          8.105959          0.026871
# 2    0.796620  0.653878         10.314323          0.024446
# 3    0.640933  0.563356          8.237822          0.023443
# 4    0.547679  0.523808          7.282034          0.023397

# %%
pred_CI_upper = df['pred0'] + 1.96 * np.sqrt(df['y_var0'])
df['pred_tr_CI_upper'] = sp.special.inv_boxcox(pred_CI_upper, lambdas.iloc[0].values)

# %%
pred_CI_lower = df['pred0'] - 1.96 * np.sqrt(df['y_var0'])
df['pred_tr_CI_lower'] = sp.special.inv_boxcox(pred_CI_lower, lambdas.iloc[0].values)

# %% [markdown]
# ## For all years

# %%
directory = 'outputs/priors_lat_lon_mat52/*'
paths = glob.glob(directory)

# %%
i = 0

for path in paths:
    print(path)
    df = pd.read_csv(path, index_col=0)
    
    # Transformed mean
    df['pred_tr'] = sp.special.inv_boxcox(df['pred0'], lambdas.iloc[i].values)
    i =+ 1
    
    # Transformed upper confidence interval
    pred_CI_upper = df['pred0'] + 1.96 * np.sqrt(df['y_var0'])
    df['pred_tr_CI_upper'] = sp.special.inv_boxcox(pred_CI_upper, lambdas.iloc[0].values)
    
    # Transformed lower confidence interval
    pred_CI_lower = df['pred0'] - 1.96 * np.sqrt(df['y_var0'])
    df['pred_tr_CI_lower'] = sp.special.inv_boxcox(pred_CI_lower, lambdas.iloc[0].values)
    
    p = path.split('/')
    df.to_csv(p[0] + '/tr_'+ p[1] + '/' + p[2])
# Out:
# outputs/priors_lat_lon_mat52/preds_1980_1981.csv
# outputs/priors_lat_lon_mat52/preds_1981_1982.csv
# outputs/priors_lat_lon_mat52/preds_1982_1983.csv
# outputs/priors_lat_lon_mat52/preds_1983_1984.csv
# outputs/priors_lat_lon_mat52/preds_1984_1985.csv
# outputs/priors_lat_lon_mat52/preds_1985_1986.csv
# outputs/priors_lat_lon_mat52/preds_1986_1987.csv
# outputs/priors_lat_lon_mat52/preds_1987_1988.csv
# outputs/priors_lat_lon_mat52/preds_1988_1989.csv
# outputs/priors_lat_lon_mat52/preds_1989_1990.csv
# outputs/priors_lat_lon_mat52/preds_1990_1991.csv
# outputs/priors_lat_lon_mat52/preds_1991_1992.csv
# outputs/priors_lat_lon_mat52/preds_1992_1993.csv
# outputs/priors_lat_lon_mat52/preds_1993_1994.csv
# outputs/priors_lat_lon_mat52/preds_1994_1995.csv
# outputs/priors_lat_lon_mat52/preds_1995_1996.csv
# outputs/priors_lat_lon_mat52/preds_1996_1997.csv
# outputs/priors_lat_lon_mat52/preds_1997_1998.csv
# outputs/priors_lat_lon_mat52/preds_1998_1999.csv
# outputs/priors_lat_lon_mat52/preds_1999_2000.csv
# outputs/priors_lat_lon_mat52/preds_2000_2001.csv
# outputs/priors_lat_lon_mat52/preds_2001_2002.csv
# outputs/priors_lat_lon_mat52/preds_2002_2003.csv
# outputs/priors_lat_lon_mat52/preds_2003_2004.csv
# outputs/priors_lat_lon_mat52/preds_2004_2005.csv
# outputs/priors_lat_lon_mat52/preds_2005_2006.csv
# outputs/priors_lat_lon_mat52/preds_2006_2007.csv
# outputs/priors_lat_lon_mat52/preds_2007_2008.csv
# outputs/priors_lat_lon_mat52/preds_2008_2009.csv
# outputs/priors_lat_lon_mat52/preds_2009_2010.csv

# %% [markdown]
# ## To netcdf

# %%
tr_directory = 'outputs/tr_priors_lat_lon_mat52/*'
tr_paths = glob.glob(tr_directory)
tr_df_all = pd.concat(map(pd.read_csv, tr_paths))

# %%
tr_df_all.drop(columns=['Unnamed: 0'], inplace=True)

# %%
tr_df_all.rename(columns={'elevation':'elev'}, inplace=True)

# %%
tr_df_all['time'] = pd.to_datetime((tr_df_all['time']-1970)*365*24*60*60*1e9).astype("datetime64[M]")

# %%
tr_df_all.isna().sum()
# Out:
# time                0
# lon                 0
# lat                 0
# elev                0
# pred0               0
# pred_low0           0
# y_var0              0
# y_var_low0          0
# pred_tr             0
# pred_tr_CI_upper    0
# pred_tr_CI_lower    0
# dtype: int64

# %%
tr_df_all
# Out:
#              time       lat       lon    elev     pred0  pred_low0    y_var0  \
# 0      1980-01-01  30.28125  81.90625  5383.0  0.314634   0.289611  2.243733
# 1      1980-01-01  30.28125  81.96875  5071.0  0.254223   0.234005  2.151837
# 2      1980-01-01  30.34375  81.46875  5446.0  0.133395   0.122786  2.498563
# 3      1980-01-01  30.34375  81.53125  5237.0  0.019359   0.017819  2.273537
# 4      1980-01-01  30.34375  81.71875  4978.0 -0.064907  -0.059745  2.139734
# ...           ...       ...       ...     ...       ...        ...       ...
# 644035 2009-12-01  32.84375  78.53125  4833.0 -0.560862  -0.543997  2.003458
# 644036 2009-12-01  32.84375  78.59375  5025.0 -0.657082  -0.637323  1.944016
# 644037 2009-12-01  32.84375  78.65625  5352.0 -0.614497  -0.596019  2.101486
# 644038 2009-12-01  32.90625  78.40625  5257.0 -0.475838  -0.461530  1.977175
# 644039 2009-12-01  32.90625  78.46875  5931.0 -0.240069  -0.232850  2.420554
#
#         y_var_low0   pred_tr  pred_tr_CI_upper  pred_tr_CI_lower
# 0         0.606565  1.365871         19.637924          0.058204
# 1         0.528705  1.287064         17.729793          0.058228
# 2         0.822474  1.142114         19.326433          0.038626
# 3         0.631817  1.019536         15.546966          0.039991
# 4         0.518450  0.937040         13.411510          0.040185
# ...            ...       ...               ...               ...
# 644035    0.595147  0.559541          8.022076          0.024546
# 644036    0.539226  0.504368          7.097675          0.022931
# 644037    0.687368  0.528166          8.118042          0.021119
# 644038    0.570421  0.612644          8.510102          0.027888
# 644039    0.987536  0.783804         13.494528          0.025974
#
# [644040 rows x 11 columns]

# %%
tr_df_all.to_csv('dataset_w_metadata/mfgp_predictions_1980_2010.csv')

# %%
tr_df_all.set_index(['time', 'lat', 'lon'], inplace=True)

# %%
ds = tr_df_all.to_xarray()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (index: 644040)
# Coordinates:
#   * index             (index) int64 0 1 2 3 4 ... 644036 644037 644038 644039
# Data variables:
#     time              (index) datetime64[ns] 1980-01-01 ... 2009-12-01
#     lat               (index) float64 30.28 30.28 30.34 ... 32.84 32.91 32.91
#     lon               (index) float64 81.91 81.97 81.47 ... 78.66 78.41 78.47
#     elev              (index) float64 5.383e+03 5.071e+03 ... 5.931e+03
#     pred0             (index) float64 0.3146 0.2542 0.1334 ... -0.4758 -0.2401
#     pred_low0         (index) float64 0.2896 0.234 0.1228 ... -0.4615 -0.2328
#     y_var0            (index) float64 2.244 2.152 2.499 ... 2.101 1.977 2.421
#     y_var_low0        (index) float64 0.6066 0.5287 0.8225 ... 0.5704 0.9875
#     pred_tr           (index) float64 1.366 1.287 1.142 ... 0.5282 0.6126 0.7838
#     pred_tr_CI_upper  (index) float64 19.64 17.73 19.33 ... 8.118 8.51 13.49
#     pred_tr_CI_lower  (index) float64 0.0582 0.05823 0.03863 ... 0.02789 0.02597

# %%
ds.attrs['title'] = 'Downscaled ERA5 monthly precipitation data using Multi-Fidelity Gaussian Processes between 1980 and 2010 for the Upper Beas and Sutlej Basins, Himalayas'

# %%
ds.attrs['institutions'] = 'University of Cambridge, British Antactic Survey'

# %%
#ds.attrs['source'] = 'Statiscally downscaled climate reanalysis data'

# %%
ds.to_netcdf('dataset_w_metadata/mfgp_predictions_1980_2010.nc')

# %%
list(ds)
# Out:
# ['elev',
#  'pred0',
#  'pred_low0',
#  'y_var0',
#  'y_var_low0',
#  'pred_tr',
#  'pred_tr_CI_upper',
#  'pred_tr_CI_lower']

# %%
import pandas as pd
import numpy as np
import scipy as sp

# Read in the data
df = pd.read_csv('dataset_w_metadata/mfgp_predictions_1980_2010.csv', index_col=0)

# Read in the scaling factors
scaling_df = pd.read_csv(
    'dataset_w_metadata/lambdas_1980_2010.csv', index_col=0)

# For 1980
df_subset = df.set_index('time')['1980-01-01' :'1981-01-01']

# %%
lambda_1980 = scaling_df[scaling_df['year'] == 1980]['lambdas'].values[0]

# %%
lambda_1980.values[0]
# Out:
# 0.0581043744313327

# %%
# Mean
df_subset['pred_tr'] = sp.special.inv_boxcox(df_subset['pred0'], lambda_1980)

# Upper 95% confidence interval bound
pred_CI_upper = df_subset['pred0'] + 1.96 * np.sqrt(df_subset['y_var0'])
df_subset['pred_tr_CI_upper'] = sp.special.inv_boxcox(pred_CI_upper, lambda_1980)

# Lower 95% confidence interval bound
pred_CI_lower = df_subset['pred0'] - 1.96 * np.sqrt(df_subset['y_var0'])
df_subset['pred_tr_CI_lower'] = sp.special.inv_boxcox(pred_CI_lower, lambda_1980)

# %%
df_subset
# Out:
#                  lat       lon    elev     pred0  pred_low0    y_var0  \
# time
# 1980-01-01  30.28125  81.90625  5383.0  0.314634   0.289611  2.243733
# 1980-01-01  30.28125  81.96875  5071.0  0.254223   0.234005  2.151837
# 1980-01-01  30.34375  81.46875  5446.0  0.133395   0.122786  2.498563
# 1980-01-01  30.34375  81.53125  5237.0  0.019359   0.017819  2.273537
# 1980-01-01  30.34375  81.71875  4978.0 -0.064907  -0.059745  2.139734
# ...              ...       ...     ...       ...        ...       ...
# 1981-01-01  32.84375  78.53125  4833.0 -0.375613  -0.337777  2.462890
# 1981-01-01  32.84375  78.59375  5025.0 -0.466231  -0.419267  2.389821
# 1981-01-01  32.84375  78.65625  5352.0 -0.442951  -0.398332  2.549374
# 1981-01-01  32.90625  78.40625  5257.0 -0.369841  -0.332587  2.430820
# 1981-01-01  32.90625  78.46875  5931.0 -0.178536  -0.160552  3.008447
#
#             y_var_low0   pred_tr  pred_tr_CI_upper  pred_tr_CI_lower
# time
# 1980-01-01    0.606565  1.365871         19.637924          0.058204
# 1980-01-01    0.528705  1.287064         17.729793          0.058228
# 1980-01-01    0.822474  1.142114         19.326433          0.038626
# 1980-01-01    0.631817  1.019536         15.546966          0.039991
# 1980-01-01    0.518450  0.937040         13.411510          0.040185
# ...                ...       ...               ...               ...
# 1981-01-01    1.162913  0.684017         12.284404          0.021232
# 1981-01-01    1.103823  0.623340         10.911946          0.020077
# 1981-01-01    1.232851  0.638425         12.138703          0.018240
# 1981-01-01    1.136978  0.688064         12.133227          0.021930
# 1981-01-01    1.604096  0.835714         19.156664          0.018110
#
# [23257 rows x 10 columns]
